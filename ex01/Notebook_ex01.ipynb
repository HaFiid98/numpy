# %% [markdown]
# ## Numpy Arrays :
#   * unlike List in python that can contain any type because it dynamicaly type and under the hood everything in Python is a Python object that hold below data:
#   ![image.png](attachment:image.png)
#
#    1. the ob_refnct : is the reference count how many is pointing to the object when is 0 the get collected by gc
#    2. the ob_size : is the actual size of that data member
#    3. ob_type : is the type of that data
#    4. ob_digit: is the actual value
#
#    * the problem is a list of the same types will contain redudant data and make an ovehead in the memory unlike c arrays for example
#    * that contain the direct adrress of byte in memory , the what make numpy array effective they have the same analogy as the c arrays  look example below :
#   ![image-2.png](attachment:image-2.png)
#    * the numpy array contain Homogenoues object meaning the same type and size , if u try to have multiple type it will be up casted to a type higher
#    * ex : [1 , 1.3] -> [1.0 , 1.3]

# %%
import numpy as np
Dict = {"name" : "JOHN" , "age" : 28}   
L = [10 , "hello" , 3.14]
T = (10 , 20)
S = set([10 , 10 ,20])
Str = "Hello"
B = True

ListOfAllJacks = [L , T , S , Str , B];
print(ListOfAllJacks)
# A = np.array([L , T  , S , B])
# for i in A: print(type(i))
# Out:
# [[10, 'hello', 3.14], (10, 20), {10, 20}, 'Hello', True]
